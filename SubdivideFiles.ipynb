# %%
import sys
import os
from shutil import copyfile

# %%
pwd
# Out:
# 'C:\\Users\\jeidmann\\Documents\\2-PhD\\GIS_Files'

# %%
cd E:\PR-PreMaria-Lidar-Unzipped
# Out:
# E:\PR-PreMaria-Lidar-Unzipped

# %%
filenames = os.listdir()

# %%
filenames
# Out:
# ['NED_DataDictionary.url',
#  'SpatialMetadata.url',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04503300_IMG_2018.img',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04503300_IMG_2018.img.aux.xml',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04503300_IMG_2018.img.xml',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04503300_IMG_2018_meta.xml',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04503450_IMG_2018.img',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04503450_IMG_2018.img.aux.xml',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04503450_IMG_2018.img.xml',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04503450_IMG_2018_meta.xml',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04503600_IMG_2018.img',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04503600_IMG_2018.img.aux.xml',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04503600_IMG_2018.img.xml',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04503600_IMG_2018_meta.xml',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04503750_IMG_2018.img',
# ...

# %%
for root, dirs, files in os.walk("E:/PR-PreMaria-Lidar-Unzipped"):
    for file in files:
        if file.endswith(".img"):
             newfile=+-(os.path.join(root, file))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-f1da4732ae47> in <module>()
#       2     for file in files:
#       3         if file.endswith(".img"):
# ----> 4              newfile=+-(os.path.join(root, file))
#
# TypeError: bad operand type for unary -: 'str'

# %%
text_files = [f for f in os.listdir("E:/PR-PreMaria-Lidar-Unzipped") if f.endswith('.img')]

# %%
text_files
# Out:
# ['USGS_NED_OPR_PR_PuertoRico_2015_19QGA04503300_IMG_2018.img',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04503450_IMG_2018.img',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04503600_IMG_2018.img',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04503750_IMG_2018.img',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04503900_IMG_2018.img',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04504050_IMG_2018.img',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04504200_IMG_2018.img',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04504350_IMG_2018.img',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04504500_IMG_2018.img',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04504650_IMG_2018.img',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04504800_IMG_2018.img',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04504950_IMG_2018.img',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04505100_IMG_2018.img',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04505250_IMG_2018.img',
#  'USGS_NED_OPR_PR_PuertoRico_2015_19QGA04505400_IMG_2018.img',
# ...

# %%
for filename in filenames2:
    local_filename = os.path.join('E:\PR-PreMaria-Lidar-Unzipped',filename)
    copyfile(local_filename,'C:/Users/jeidmann/Documents/2-PhD/GIS_Files/Test')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-21-2d309f5975f7> in <module>()
#       1 for filename in filenames2:
#       2     local_filename = os.path.join('E:\PR-PreMaria-Lidar-Unzipped',filename)
# ----> 3     copyfile(local_filename,'C:/Users/jeidmann/Documents/2-PhD/GIS_Files/Test')
#
# ~\AppData\Local\Continuum\anaconda3\lib\shutil.py in copyfile(src, dst, follow_symlinks)
#     119     else:
#     120         with open(src, 'rb') as fsrc:
# --> 121             with open(dst, 'wb') as fdst:
#     122                 copyfileobj(fsrc, fdst)
#     123     return dst
#
# PermissionError: [Errno 13] Permission denied: 'C:/Users/jeidmann/Documents/2-PhD/GIS_Files/Test'
